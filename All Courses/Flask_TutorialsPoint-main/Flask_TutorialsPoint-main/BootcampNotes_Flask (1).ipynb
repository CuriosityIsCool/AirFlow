# %% [markdown]
# # References

# %% [markdown]
# ## References provided by Ketan
# * Flask :- https://www.tutorialspoint.com/flask/index.htm

# %% [markdown]
# ## References BYME
#
# * https://youtu.be/Z1RJmh_OqeA
# * https://youtu.be/5aYpkLfkgRE

# %% [markdown]
# # Tutorials Point / Flask
#
# Flask is a web application framework written in Python.Flask is based on Werkzeug WSGI toolkit and Jinja2 template engine. Both are Pocco projects.
#
# This tutorial has been prepared for anyone who has a basic knowledge of Python and has an urge to develop websites.

# %% [markdown]
# ## Framework
# collection of libraries and modules that enables a web application developer to write applications without having to bother about low-level details such as protocols, thread management etc.

# %% [markdown]
# `WSGI` is a specification for a universal interface between the web server and the web applications.
#
# `Werkzeug` = WSGI toolkit, which implements requests, response objects, and other utility functions.
#
# `Jinja2` = templating engine for Python. A web templating system combines a template with a certain data source to render dynamic web pages.

# %% [markdown]
# ## Creating enviornment for Project

# %%
pip install virtualenv
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !apt install virtualenv
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# virtualenv is already the newest version (20.0.17-1ubuntu0.4).
# 0 upgraded, 0 newly installed, 0 to remove and 24 not upgraded.

# %%
# !mkdir FirstFlaskProj
# !cd FirstFlaskProj
# Out:
# mkdir: cannot create directory ‘FirstFlaskProj’: File exists

# %%
# !virtualenv enviornment_1
# Out:
# AttributeError: module 'virtualenv.create.via_global_ref.builtin.cpython.mac_os' has no attribute 'CPython2macOsFramework'

# %%
# !venv/bin/activate
# Out:
# /bin/bash: venv/bin/activate: No such file or directory

# %%
pip install flask
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !pip install flask-ngrok
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
pip install pyngrok
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# ## Run this code everytime

# %% [markdown]
# Get ngrok auth token here https://dashboard.ngrok.com/get-started/your-authtoken

# %%
from flask import Flask
from pyngrok import ngrok

ngrok.set_auth_token("------------- PASTE TOKEN HERE --------------")
port_no = 5000
public_url = ngrok.connect(port_no).public_url

print(public_url)
app = Flask(__name__)
# Out:
# WARNING:pyngrok.process.ngrok:t=2023-04-27T10:42:31+0000 lvl=warn msg="ngrok config file found at legacy location, move to XDG location" xdg_path=/root/.config/ngrok/ngrok.yml legacy_path=/root/.ngrok2/ngrok.yml
# https://c27b-35-231-7-92.ngrok-free.app

# %% [markdown]
# ## First Flask Project

# %%
@app.route('/')
def index():
  return "Aditya's First Flask Project Welcomes You !"

if __name__=="__main__":
  app.run(port = port_no)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: on
# INFO:werkzeug:WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# INFO:werkzeug:Press CTRL+C to quit
# INFO:werkzeug: * Restarting with stat

# %% [markdown]
# Output:
#
# ![Screenshot 2023-04-27 14.17.51.png](data:image/png;base64,...)

# %% [markdown]
# ### Generalized info
# * `app.route(rule=url, options)`
# route() function of the Flask class is a decorator, which tells the application which URL should call the associated function.
#
# * `app.run(host = "127.0.0.1", port = 5000, debug = False, options = "forwarded to Werkzeug server.")` run() method of Flask class runs the application on the local development server.

# %% [markdown]
# ## Decorator alternative
# ```
# @app.route(‘/hello’)
# def hello_world():
#    return ‘hello world 123’
# ```
# Above code works same as below code
# ```
# def hello_world():
#    return ‘hello world 123’
# app.add_url_rule(‘/’, ‘hello’, hello_world)
# ```

# %%
test_message = "you're doing great Aditya ! if you can see this message on webpage"

# %%
del hello

# %%
@app.route('/hello')
def hello(name="aditya"):
  print(public_url+"/"+__main__)
  return 'Hello %s!' % name

if __name__ == '__main__':
   app.run(debug = True)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-8-311623089156> in <cell line: 1>()
#       1 @app.route('/hello')
# ----> 2 def hello(name="aditya"):
#       3   print(public_url+"/"+__main__)
#       4   return 'Hello %s!' % name
#       5
#
# /usr/local/lib/python3.9/dist-packages/flask/scaffold.py in decorator(f)
#     447         def decorator(f: T_route) -> T_route:
#     448             endpoint = options.pop("endpoint", None)
# --> 449             self.add_url_rule(rule, endpoint, f, **options)
#     450             return f
#     451
#
# /usr/local/lib/python3.9/dist-packages/flask/scaffold.py in wrapper_func(self, *args, **kwargs)
#      48     def wrapper_func(self, *args: t.Any, **kwargs: t.Any) -> t.Any:
#      49         self._check_setup_finished(f_name)
# ---> 50         return f(self, *args, **kwargs)
#      51
# ...

# %% [markdown]
#   Output: (I don'nt know why but it keeps after I click `visit site` loading and loading...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#del test # to avoid this error (AssertionError: View function mapping is overwriting an existing endpoint function: test)

@app.route('/test2')
def test2(test_message):
  print(public_url) ####################
  return test_message

if __name__ == '__main__':
   app.run(debug = True, header=ngrok-skip-browser-warning:true])
# Out:
#   File "<ipython-input-33-a2bc8584ce8f>", line 9
#     app.run(debug = True, header=ngrok-skip-browser-warning:true])
#                                                            ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Doubt:
# I dont know why am i not getting a output of other codes except the first `index()` code.

# %% [markdown]
# ## Getting values from url
#
# ```
# @app.route('/blog/<int:postID>')
# def show_blog(postID):
#    return 'Blog Number %d' % postID
#
# @app.route('/rev/<float:revNo>')
# def revision(revNo):
#    return 'Revision Number %f' % revNo
# ```

# %% [markdown]
# ## Trying on local machine

# %%
from flask import Flask
app = Flask(__name__)

@app.route('/flask')
def hello_flask():
   return 'Hello Flask'

@app.route('/python/')
def hello_python():
   return 'Hello Python'

if __name__ == '__main__':
   app.run()

# %% [markdown]
# Output: (works fine, maybe i need to learn by ngrok)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Flask – URL Building
# * `flask.redirect(url)` = redirect
# * `url_for("func_name")`

# %% [markdown]
# ## Flask – HTTP methods
# 1.
# GET
#
# Sends data in unencrypted form to the server. Most common method.
#
# 2.
# HEAD
#
# Same as GET, but without response body
#
# 3.
# POST
#
# Used to send HTML form data to server. Data received by POST method is not cached by server.
#
# 4.
# PUT
#
# Replaces all current representations of the target resource with the uploaded content.
#
# 5.
# DELETE
#
# Removes all current representations of the target resource given by a URL
#
#
# ###Example
# ```
# user = request.form['nm']
# User = request.args.get(‘nm’)
# ```

# %% [markdown]
# ## sending html code
# Example: `render_template(‘hello.html’)` returns `<html><body><h1>Hello World</h1></body></html>`

# %% [markdown]
# ## placeholder `{{ var_name }}`
# The following code is saved as hello.html in the templates folder.
#
# ```
# <!doctype html>
# <html>
#    <body>
#
#       <h1>Hello {{ name }}!</h1>
#
#    </body>
# </html>
# ```
#
# Next, run the following script from Python shell.
#
# ```
# from flask import Flask, render_template
# app = Flask(__name__)
#
# @app.route('/hello/<user>')
# def hello_name(user):
#    return render_template('hello.html', name = user)
#
# if __name__ == '__main__':
#    app.run(debug = True)
# ```
# ```
# As the development server starts running, open the browser and enter URL as − http://localhost:5000/hello/mvl
# ```
# The variable part of URL is inserted at {{ name }} place holder.

# %% [markdown]
# Run the following code from Python shell.
#
# ```
# from flask import Flask, render_template
# app = Flask(__name__)
#
# @app.route('/result')
# def result():
#    dict = {'phy':50,'che':60,'maths':70}
#    return render_template('result.html', result = dict)
#
# if __name__ == '__main__':
#    app.run(debug = True)
# ```
# Save the following HTML script as result.html in the templates folder.
# ```
# <!doctype html>
# <html>
#    <body>
#       <table border = 1>
#          {% for key, value in result.items() %}
#             <tr>
#                <th> {{ key }} </th>
#                <td> {{ value }} </td>
#             </tr>
#          {% endfor %}
#       </table>
#    </body>
# </html>
# ```
# Here, again the Python statements corresponding to the For loop are enclosed in {%..%} whereas, the expressions key and value are put inside {{ }}.

# %% [markdown]
# ## Flask – Static Files
# must read https://www.tutorialspoint.com/flask/flask_static_files.htm

# %% [markdown]
# ##Flask – Request Object (request data)
#
# Form − It is a dictionary object containing key and value pairs of form parameters and their values.
#
# args − parsed contents of query string which is part of URL after question mark (?).
#
# Cookies − dictionary object holding Cookie names and values.
#
# files − data pertaining to uploaded file.
#
# method − current request method.

# %% [markdown]
# ## Flask – Sending Form Data to Template
# https://www.tutorialspoint.com/flask/flask_sending_form_data_to_template.htm

# %% [markdown]
# ## Flask – Mail
# a good example of building mail here https://www.tutorialspoint.com/flask/flask_mail.htm

# %% [markdown]
# ##Flask – SQLite
# example of Using sqlite database with flask here https://www.tutorialspoint.com/flask/flask_sqlite.htm

# %% [markdown]
# # Summary
#
# * `flask-WTF` = WTForms, a flexible form, rendering and validation library. (HTML provides a `<form>` tag. Form has elements such as text input, radio, select etc.)
#
# * `sqlite3` = use `connect('database.db')`, `connection.execute("query")` and `connection.close()`
#   ```
#   import sqlite3
#
#   conn = sqlite3.connect('database.db')
#   print "Opened database successfully";
#
#   conn.execute('CREATE TABLE students (name TEXT, addr TEXT, city TEXT, pin TEXT)')
#   print "Table created successfully";
#   conn.close()
#   ```
#
# * `flask-sqlalchemy` = SQLAlchemy, a Python toolkit is a powerful Object Relation Mapper that gives application developers the full power and flexibility of SQL.
#
# * `flask-sijax` = Sijax stands for ‘Simple Ajax’ and it is a Python/jQuery library designed to help you easily bring Ajax to your application.
#
#   AJAX (Asynchronous JavaScript and XML) is a technology used in web development to send and receive data from a server without reloading the entire web page.
#
# * `mod_wsgi` (Deployment Application) is an Apache module that provides a WSGI compliant interface for hosting Python based web applications on Apache server.
#
# * `flup.server.fcgi.WSGIServer` FastCGI is another deployment option for Flask application on web servers like nginix, lighttpd, and Cherokee.

# %% [markdown]
# # My review
# I really need hands-on practice although i have referred some flask website design videos also.
#
# So i will do it hands-on when I have some free time.
