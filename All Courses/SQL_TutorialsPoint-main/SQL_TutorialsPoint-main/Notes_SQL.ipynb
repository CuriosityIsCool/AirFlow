# %% [markdown]
# # Resources

# %% [markdown]
# ##Ketan Resources:
# * SQL :- https://www.tutorialspoint.com/sql/index.htm

# %% [markdown]
# #Tutorials Point / SQL

# %% [markdown]
# ## SQL - Overview

# %% [markdown]
# SQL is the standard language to communicate with Relational Database Systems. All the Relational Database Management Systems (RDMS) like MySQL, MS Access, Oracle, Sybase, Informix, Postgres and SQL Server use SQL as their Standard Database Language.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### SQL Basic Commands
# ####DDL - Data Definition Language
#
# 1
# CREATE
#
# Creates a new table, a view of a table, or other object in the database.
#
# 2
# ALTER
#
# Modifies an existing database object, such as a table.
#
# 3
# DROP
#
# Deletes an entire table, a view of a table or other objects in the database.
#
# ####DML - Data Manipulation Language
#
# 1
# SELECT
#
# Retrieves certain records from one or more tables.
#
# 2
# INSERT
#
# Creates a record.
#
# 3
# UPDATE
#
# Modifies records.
#
# 4
# DELETE
#
# Deletes records.
#
# ####DCL - Data Control Language
#
# 1
# GRANT
#
# Gives a privilege to user.
#
# 2
# REVOKE
#
# Takes back privileges granted from user.

# %% [markdown]
# ### Doubt:
# Difference between Primary Kry AND Foreign key ?

# %% [markdown]
# ## SQL - RDBMS Databases

# %% [markdown]
# ### Features
# * Users can create tables, queries, forms and reports and connect them together with macros.
#
# * Option of importing and exporting the data to many formats including Excel, Outlook, ASCII, dBase, Paradox, FoxPro, SQL Server, Oracle, ODBC, etc.
#
# * There is also the Jet Database format (MDB or ACCDB in Access 2007), which can contain the application and data in one file. This makes it very convenient to distribute the entire application to another user, who can run it in disconnected environments.
#
# * Microsoft Access offers parameterized queries. These queries and Access tables can be referenced from other programs like VB6 and .NET through DAO or ADO.
#
# * The desktop editions of Microsoft SQL Server can be used with Access as an alternative to the Jet Database Engine.
#
# * Microsoft Access is a file server-based database. Unlike the client-server relational database management systems (RDBMS), Microsoft Access does not implement database triggers, stored procedures or transaction logging.

# %% [markdown]
# ## SQL - Syntax
#
# refer https://www.tutorialspoint.com/sql/sql-syntax.htm for a short and good syntax revision

# %% [markdown]
# ## SQL - Data Types
#
# https://www.tutorialspoint.com/sql/sql-data-types.htm
#
# Observation Byme:
# `var` represents variable i.e. changing
# * for Example
#
#   `char(n)` holds the character string with the fixed width, While `varchar(n)` holds the character string with the variable width.
#
#   where `n` = number of character (CHECK)

# %% [markdown]
# A Unicode string is a sequence of Unicode characters, where each character is represented by a unique code point. Unicode is a universal character encoding standard that supports characters from many different scripts and languages. Unicode strings are typically represented using UTF-8, UTF-16, or UTF-32 encoding schemes.
#
# Here's an example of a Unicode string in Python:
#
# In this example, the string contains characters from English, Japanese, and Russian scripts.

# %%
print(unicode_string := "Hello, こんにちは, привет")
# Out:
# Hello, こんにちは, привет

# %% [markdown]
# A binary string, on the other hand, is a sequence of 0s and 1s that represents binary data. Binary strings are often used in computer programming to represent machine instructions, network packets, or binary file formats.
#
# Here's an example of a binary string in Python:
#
# In this example, the binary string represents the ASCII characters for "Hello World!". The b prefix indicates that this is a binary string, and each character is represented using its ASCII code in hexadecimal notation.

# %%
print(binary_string := b'\x48\x65\x6c\x6c\x6f\x20\x57\x6f\x72\x6c\x64\x21')
# Out:
# b'Hello World!'

# %% [markdown]
# ## SQL - Operators

# %% [markdown]
# ### SQL Logical Operators
# Here is a list of all the logical operators available in SQL.
#
#
#
# 1.	ALL
#
# The ALL operator is used to compare a value to all values in another value set.
#
# 2. AND
#
# The AND operator allows the existence of multiple conditions in an SQL statement's WHERE clause.
#
# 3. ANY
#
# The ANY operator is used to compare a value to any applicable value in the list as per the condition.
#
# 4. BETWEEN
#
# The BETWEEN operator is used to search for values that are within a set of values, given the minimum value and the maximum value.
#
# 5. EXISTS
#
# The EXISTS operator is used to search for the presence of a row in a specified table that meets a certain criterion.
#
# 6. IN
#
# The IN operator is used to compare a value to a list of literal values that have been specified.
#
# 7. LIKE
#
# The LIKE operator is used to compare a value to similar values using wildcard operators.
#
# 8. NOT
#
# The NOT operator reverses the meaning of the logical operator with which it is used. Eg: NOT EXISTS, NOT BETWEEN, NOT IN, etc. This is a negate operator.
#
# 9. OR
#
# The OR operator is used to combine multiple conditions in an SQL statement's WHERE clause.
#
# 10. IS NULL
#
# The NULL operator is used to compare a value with a NULL value.
#
# 11. UNIQUE
#
# The UNIQUE operator searches every row of a specified table for uniqueness (no duplicates).

# %% [markdown]
# ##SQL - Expressions
# refer https://www.tutorialspoint.com/sql/sql-expressions.htm for short and simple explanation
