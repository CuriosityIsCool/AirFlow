# %% [markdown]
# # Resources

# %% [markdown]
# ## Resources by Ketan
# * SnowFlake :- https://www.tutorialspoint.com/snowflake/index.htm

# %% [markdown]
# ## Other Valueable resources BYME
# - Snowflake Tutorial from the official documentation: https://docs.snowflake.com/en/user-guide/getting-started-tutorials.html
# - Snowflake Tutorial from DataCamp: https://www.datacamp.com/community/tutorials/snowflake-tutorial

# %% [markdown]
# ## Actually Referred Extras
# * Airflow Data Pipeline with AWS and Snowflake for Beginners | Project - `Data with Marc`
# https://youtu.be/wT67h9qDl1o

# %% [markdown]
# # Tutorials Point / Snowflake

# %% [markdown]
# ## introduction
# * Snowfalke is OLAP
# Snowflake is advanced solution for OLAP (Online Analytical Processing) technology. OLAP is also known as online data retrieving and data analysis system using historical data. It processes complex and aggregated queries with low number of transactions.
#
# For Ex: Getting number of orders, sales amount in last month for a company, number of new users list in the company in last quarter etc
#
#
# *Snowflake is not used as OLTP (Online Transactional Processing) database. OLTP database usually contains real time data with a high volume of small data transactions.
#
# For Ex: Inserting customer's order detail, register a new customer, tracking order delivery status etc.

# %% [markdown]
# ## Data Architecture
#
# * Snowflake data architecture re-invents a new SQL query engine. It is designed for the cloud only. Snowflake doesn't utilize or built on top of any existing database technology.

# %% [markdown]
# Snowflake's data architecture has three main layers −
#
# * Database Storage
# * Query Processing
# * Cloud Services
#
# Following is the data architecture diagram of Snowflake −
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ###Database Storage
# Snowflake supports Amazon S3, Azure and Google Cloud to load data into Snowflake using file system. User should upload a file (.csv, .txt, .xlsx etc.) into the cloud and after they create a connection in Snowflake to bring the data. Data size is `unlimited`, but file size is up to `5GB` as per cloud services.

# %% [markdown]
# ###Query Processing
# Query execution is a part of processing layer or compute layer. To process a query, Snowflake requires compute environment, known as "Virtual Warehouse" in Snowflake's world. Virtual warehouse is a compute cluster. A virtual warehouse consists of CPU, Memory and temporary storage system.
#
# #### number of servers depends on size of virtual warehouses
# For example,
# * XSmall warehouse has 1 Server per cluster,
# * while a Small Warehouse has 2 Servers per cluster
# * and it gets double on increasing the size such as Large, XLarge, etc.

# %% [markdown]
# ### Cloud Services
# Cloud Service is the 'Brain' of the Snowflake. It coordinates and manages activities across Snowflake.
#
# * It is the centralized management for all storage.
# * It manages the compute environments to work with storage.
# * Security like Authentication, Access controls based on roles and users
# * It performs encryption as well as key management services.
# * etc....

# %% [markdown]
# ## Functional Architecture
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## How to Access
# * create aws
# * start 30 day free (Business Critical) trial

# %% [markdown]
# ## Some AWS issues
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Since AWS issue,
# I just started with randomlyselecting `Asia Pacific (Mumbai)` as my AWS server
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Table & View Types
#
# ### Tables
# * Permanent Table (default, only Fail-safe, protected)
#
#   * Permanent tables are created in the database.
#   * These tables persist until deleted or dropped from database.
#
# * Temporary Table
#   * Persist for a session.
#
# * Transient Table
#   * These tables persist until the users drop or delete them.
#   * Multiple users can access a transient table.
#
# * External Table
#   * These tables persist until removed.
#   * External tables are only meant for reading.
#
# ### Views
# * Standard View (default)
#   * Select queries for tables to view data.
#
# * Secure View (accessed only by authorized users)
#   * Authorized users can view the definition and details.
#
# * Materialized View (auto-refreshed)

# %% [markdown]
# ## Warehouse
#
# can be created using following query:
# ```
# CREATE WAREHOUSE "TEST_WH"
# WITH WAREHOUSE_SIZE = 'SMALL'
# AUTO_SUSPEND = 600
# AUTO_RESUME = TRUE
# MIN_CLUSTER_COUNT = 1
# MAX_CLUSTER_COUNT = 2
# SCALING_POLICY = 'STANDARD'
# COMMENT = ' '
# ```

# %% [markdown]
# Observation: UI of snowflake is totally different from what shown in Tutorials point.

# %% [markdown]
# Tutorials point showing UI of SnowFlake:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Current UI of SnowFlake:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Sample Useful Queries
# https://www.tutorialspoint.com/snowflake/snowflake_sample_useful_queries.htm

# %% [markdown]
# ## BYME: Using SQL Worksheet in SnowFlake
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# We can also see that chart of changing `Col1` values
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## BYME: My Warehouse
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## My History
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## External Data Loading (from AWS S3)
#
# refer https://www.tutorialspoint.com/snowflake/snowflake_external_data_loading.htm

# %% [markdown]
# ## External Data Unloading (Into AWS S3)
#
# refer https://www.tutorialspoint.com/snowflake/snowflake_external_data_unloading.htm

# %% [markdown]
# Not tried `External Data Loading (from AWS S3)` and `External Data Unloading (Into AWS S3)` since my AWS account is not created.
#
# But, I have seen a YouTube video of doing these.
