# %% [markdown]
# # Resources

# %% [markdown]
# ## Ketan Resources
# * SparkSQL :- https://www.tutorialspoint.com/spark_sql/index.htm

# %% [markdown]
# # Tutorials Point / SparkSQL

# %% [markdown]
# ## Spark SQL Tutorial
# Apache Spark is a lightning-fast cluster computing designed for fast computation. It was built on top of Hadoop MapReduce and it extends the MapReduce model to efficiently use more types of computations which includes Interactive Queries and Stream Processing.

# %% [markdown]
# ### Prerequisites
# * Scala programming
# * database concepts
# * Linux operating system

# %% [markdown]
# ## Spark - Introduction
# Industries are using Hadoop extensively to analyze their data sets.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * HDFS = Hadoop Distributed File System

# %% [markdown]
# ## Spark – RDD

# %% [markdown]
# ### Iterative Operations on Spark RDD
#
# If the Distributed memory (RAM) is not sufficient to store intermediate results (State of the JOB), then it will store those results on the disk.

# %% [markdown]
# * MR = MapReduce (CHECK)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Interactive Operations on Spark RDD
#
# If different queries are run on the same set of data repeatedly, this particular data can be kept in memory for better execution times.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Spark SQL - DataFrames
# These are very very similar to PySpark DataFrame.
#
# ### SparkSQL supports two different methods for converting existing RDDs into DataFrames −

# %%
from IPython.core.display import HTML

# %%
table1= '''<table class="table table-bordered">
<tbody><tr>
<th style="width:13%;">Sr. No</th>
<th style="text-align:center;">Methods &amp; Description</th>
</tr>
<tr>
<td>1</td>
<td><a href="/spark_sql/inferring_schema_using-reflection.htm">Inferring the Schema using Reflection</a>
<p>This method uses reflection to generate the schema of an RDD that contains specific types of objects.</p></td>
</tr>
<tr>
<td>2</td>
<td><a href="/spark_sql/programmatically_specifying_schema.htm">Programmatically Specifying the Schema</a>
<p>The second method for creating DataFrame is through programmatic interface that allows you to construct a schema and then apply it to an existing RDD.</p></td>
</tr>
</tbody></table>'''
HTML(table1)
# Out:
# <table class="table table-bordered">
# <tbody><tr>
# <th style="width:13%;">Sr. No</th>
# <th style="text-align:center;">Methods &amp; Description</th>
# </tr>
# <tr>
# <td>1</td>
# <td><a href="/spark_sql/inferring_schema_using-reflection.htm">Inferring the Schema using Reflection</a>
# <p>This method uses reflection to generate the schema of an RDD that contains specific types of objects.</p></td>
# </tr>
# <tr>
# <td>2</td>
# <td><a href="/spark_sql/programmatically_specifying_schema.htm">Programmatically Specifying the Schema</a>
# <p>The second method for creating DataFrame is through programmatic interface that allows you to construct a schema and then apply it to an existing RDD.</p></td>
# </tr>
# </tbody></table>

# %% [markdown]
# ## Spark SQL - Data Sources

# %% [markdown]
# ### some data sources available in SparkSQL

# %% [markdown]
# ### Trying to view table as JSON (does'nt work here)
#
# [{"Sr. No":"1",	"Data Sources":"JSON Datasets:Spark SQL can automatically capture the schema of a JSON dataset and load it as a DataFrame."},{"Sr. No":"2",	"Data Sources":"Hive Tables comes bundled with the Spark library as HiveContext, which inherits from SQLContext."},{"Sr. No":"3",	"Data Sources":"Parquet Files is a columnar format, supported by many data processing systems"}]

# %%
HTML('''<table class="table table-bordered">
<tbody><tr>
<th style="width:10%;">Sr. No</th>
<th>Data Sources</th>
</tr>
<tr>
<td>1</td>
<td><a href="/spark_sql/spark_sql_json_datasets.htm">JSON Datasets</a>
<p>Spark SQL can automatically capture the schema of a JSON dataset and load it as a DataFrame.</p></td>
</tr>
<tr>
<td>2</td>
<td><a href="/spark_sql/spark_sql_hive_tables.htm">Hive Tables</a>
<p>Hive comes bundled with the Spark library as HiveContext, which inherits from SQLContext.</p></td>
</tr>
<tr>
<td>3</td>
<td><a href="/spark_sql/spark_sql_parquet_files.htm">Parquet Files</a>
<p>Parquet is a columnar format, supported by many data processing systems.</p></td>
</tr>
</tbody></table>''')
# Out:
# <table class="table table-bordered">
# <tbody><tr>
# <th style="width:10%;">Sr. No</th>
# <th>Data Sources</th>
# </tr>
# <tr>
# <td>1</td>
# <td><a href="/spark_sql/spark_sql_json_datasets.htm">JSON Datasets</a>
# <p>Spark SQL can automatically capture the schema of a JSON dataset and load it as a DataFrame.</p></td>
# </tr>
# <tr>
# <td>2</td>
# <td><a href="/spark_sql/spark_sql_hive_tables.htm">Hive Tables</a>
# <p>Hive comes bundled with the Spark library as HiveContext, which inherits from SQLContext.</p></td>
# </tr>
# <tr>
# <td>3</td>
# <td><a href="/spark_sql/spark_sql_parquet_files.htm">Parquet Files</a>
# <p>Parquet is a columnar format, supported by many data processing systems.</p></td>
# </tr>
# </tbody></table>

# %% [markdown]
# # YouTube / Spark SQL Tutorial For Beginners | Apache Spark Tutorial For Beginners - `Simplilearn`
#
# https://youtu.be/5X4j_AFrrGI
#
# Watched some part of this video but not done it hands-on.

# %% [markdown]
# * use `spark_df.sql("any sql query")` to run sql queries on `spark_df` dataframe
# * use `spark.read.load("file link")` to load a file and form dataframe
# * use `output_df.write.format("json").save("output_file_name")` to export `output_df` in `json` format to `output_file_name` file
