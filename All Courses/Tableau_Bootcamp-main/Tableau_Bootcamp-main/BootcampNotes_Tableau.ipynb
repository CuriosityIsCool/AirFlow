# %% [markdown]
# # Resources

# %% [markdown]
# ##Resources provided by Ketan
# * Tableau :- https://www.tutorialspoint.com/tableau/index.htm

# %% [markdown]
# ## My References
# * Data Visualization with Tableau | Tableau Tutorial for Beginners in 2022 | - `Great Learning` - https://youtu.be/WAXfRAI96YA
# * Learn Data Story telling on Tableau 2022 in 7 mins - `SkillCurb` - https://youtu.be/avjsxRHlFSM

# %% [markdown]
# # Tutorials Point / Tableau
#
# Tableau is a Business Intelligence tool for visually analyzing the data. Tableau can connect to files, relational and Big Data sources to acquire and process data. The software allows data blending and real-time collaboration, which makes it very unique.

# %% [markdown]
# ## Tableau - Get Started
# These three steps are −
#
# 1. Connect to a data source − It involves locating the data and using an appropriate type of connection to read the data.
#
# 2. Choose dimensions and measures − This involves selecting the required columns from the source data for analysis.
#
# 3. Apply visualization technique − This involves applying required visualization methods, such as a specific chart or graph type to the data being analyzed.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Tableau - Design Flow
#
# ![image.png](data:image/png;base64,...)

# %%
from IPython.core.display import HTML

# %%
table1= '''<table class="table table-bordered">
<tbody><tr>
<th style="text-align:center;">Data Type</th>
<th style="text-align:center;">Description</th>
<th style="text-align:center;">Example</th>
</tr>
<tr>
<td style="text-align:center; vertical-align:middle;"><b>STRING</b></td>
<td style="vertical-align:middle;">Any sequence of zero or more characters. They are enclosed within single quotes. The quote itself can be included in a string by writing it twice.</td>
<td><p style="text-align:center;">'Hello' 'Quoted' 'quote'</p></td>
</tr>
<tr>
<td style="text-align:center; vertical-align:middle;"><b>NUMBER</b></td>
<td style="vertical-align:middle;">These are either integers or floating points. It is advised to round the floating point numbers while using them in calculations.</td>
<td><p style="text-align:center;">3</p> 
<p style="text-align:center;">142.58</p></td>
</tr>
<tr>
<td style="text-align:center; vertical-align:middle;"><b>BOOLEAN</b></td>
<td style="text-align:center; vertical-align:middle;">They are logical values.</td>
<td><p style="text-align:center;">TRUE</p> 
<p style="text-align:center;">FALSE</p></td>
</tr>
<tr>
<td style="text-align:center; vertical-align:middle;"><b>DATE &amp; DATETIME</b></td>
<td style="vertical-align:middle;">Tableau recognizes dates in almost all formats. But in case we need to force Tableau to recognize a string as date, then we put a # sign before the data.</td>
<td><p style="text-align:center;">"02/01/2015"</p> 
<p style="text-align:center;">"#3 March 1982"</p></td>
</tr>
</tbody></table>'''
HTML(table1)
# Out:
# <table class="table table-bordered">
# <tbody><tr>
# <th style="text-align:center;">Data Type</th>
# <th style="text-align:center;">Description</th>
# <th style="text-align:center;">Example</th>
# </tr>
# <tr>
# <td style="text-align:center; vertical-align:middle;"><b>STRING</b></td>
# <td style="vertical-align:middle;">Any sequence of zero or more characters. They are enclosed within single quotes. The quote itself can be included in a string by writing it twice.</td>
# <td><p style="text-align:center;">'Hello' 'Quoted' 'quote'</p></td>
# </tr>
# <tr>
# <td style="text-align:center; vertical-align:middle;"><b>NUMBER</b></td>
# <td style="vertical-align:middle;">These are either integers or floating points. It is advised to round the floating point numbers while using them in calculations.</td>
# <td><p style="text-align:center;">3</p>
# <p style="text-align:center;">142.58</p></td>
# </tr>
# <tr>
# <td style="text-align:center; vertical-align:middle;"><b>BOOLEAN</b></td>
# ...

# %% [markdown]
# ## Tableau - Data Terminology
#
# * Workbook
#
# A file with a .twb extension that contains one or more worksheets (and possibly also dashboards and stories).
#
# * Worksheet
#
# A sheet where you build views of your data by dragging fields onto shelves.

# %% [markdown]
# # YoutTube / Data Visualization with Tableau | Tableau Tutorial for Beginners in 2022 | - `Great Learning`

# %% [markdown]
# 2 Types of Variables:
# 1. Measure `#` : Values that can be aggrigated (eg `int`)
# 2. Dimensions `Abc` = categorical values (eg `str`, `date`)
# 3. Geographical values `Globe Symbol` : location

# %% [markdown]
# ## Downloaded Data
# https://www.kaggle.com/datasets/rajkumarpandey02/gdp-in-usd-per-capita-income-by-country?resource=download

# %% [markdown]
# ## Created a Barchart in Tableau
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Some Changes in row column can be used to group contries based on continents
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Applied Color
# (Drag and drop `World Bank` to colour icon)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# similarly, changing color by continent name
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Creating new fileds `=Abc`
#
# click `Analysis` / `Create Calculated Fields`
#
# Example 1:
# Creating a field named `F1*F5_Calculatedfield` that returns multiplication of F1 and F5

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Field created
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Using that calculated field
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Example of a story by instructor

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #Summary byme
# 1. Data Sources (get data in form of table from eg. `.csv` file)
# 2. Sheets (make graphs like representations of data)
# 3. Dashboard (combine those sheets to show in 1 page called dashboard)
# 4. Story (sequential pages having sheets and dashboards like powerpoint)
